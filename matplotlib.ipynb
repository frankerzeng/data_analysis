# %%
import matplotlib.pyplot as plt

# %%
y=[2,1,3,43,5,65,3,3,3,4,56]

# %%
x=range(2,24,2)

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
x1=[1,2,3,4,5]

# %%
y1=[2.9,3,3,3.3,3.4]

# %%
plt.scatter(x1,y1)

# %%
x2=range(4)

# %%
y2=[2,3,1,8]

# %%
plt.bar(x2,y2)
# Out:
# <BarContainer object of 4 artists>
